# %%
import json
from tqdm import tqdm
from bs4 import BeautifulSoup
import xml.etree.ElementTree as ElT
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import pandas as pd

from pathlib import Path
import sys
sys.path.append("..")
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

df = pd.read_csv(Path('../data/writers.csv'))

# %%
df["AnswerCount"] = df["AnswerCount"].fillna(-1)
# Out:
#        Unnamed: 0  AcceptedAnswerId  AnswerCount  \
# 0               0              15.0          9.0
# 1               1              16.0          7.0
# 2               2              31.0          5.0
# 3               3               NaN          7.0
# 4               4              85.0         10.0
# ...           ...               ...          ...
# 34325       34325               NaN          NaN
# 34326       34326               NaN          1.0
# 34327       34327               NaN          NaN
# 34328       34328               NaN          1.0
# 34329       34329               NaN          NaN
#
#                                                     Body ClosedDate  \
# 0      <p>I've always wanted to start writing (in a t...        NaN
# 1      <p>What kind of story is better suited for eac...        NaN
# 2      <p>I finished my novel, and everyone I've talk...        NaN
# 3      <p>When writing a short-story to highlight a c...        NaN
# 4      <p>I keep hearing about literary fiction, and ...        NaN
# ...                                                  ...        ...
# 34325  <p><a href="https://writing.stackexchange.com/...        NaN
# 34326  <p>I have an experiment which we call 'the kry...        NaN
# 34327  <p>Only if <em>Krypton</em> is a proper noun, ...        NaN
# 34328  <p>I am new to the art of writing and have bee...        NaN
# 34329  <p>The best way I know of is to make the reade...        NaN
#
#        CommentCount CommunityOwnedDate             CreationDate  \
# 0                 7                NaN  2010-11-18T20:40:32.857
# 1                 0                NaN  2010-11-18T20:42:31.513
# 2                 1                NaN  2010-11-18T20:43:28.903
# 3                 0                NaN  2010-11-18T20:43:59.693
# 4                 1                NaN  2010-11-18T20:45:44.067
# ...             ...                ...                      ...
# 34325             0                NaN  2019-03-03T02:38:35.803
# 34326             0                NaN  2019-03-03T02:45:50.430
# 34327             0                NaN  2019-03-03T03:11:50.520
# 34328             0                NaN  2019-03-03T03:17:39.297
# 34329             0                NaN  2019-03-03T03:35:08.283
#
#        FavoriteCount     Id  ... LastEditorUserId OwnerDisplayName  \
# 0               17.0      1  ...          32946.0              NaN
# 1                5.0      2  ...              NaN              NaN
# 2               10.0      3  ...          23159.0              NaN
# 3                4.0      5  ...              NaN              NaN
# 4                5.0      7  ...             25.0              NaN
# ...              ...    ...  ...              ...              ...
# 34325            NaN  42881  ...              NaN              NaN
# 34326            NaN  42882  ...              NaN              NaN
# 34327            NaN  42883  ...          23253.0              NaN
# 34328            NaN  42884  ...          36999.0              NaN
# 34329            NaN  42885  ...              NaN              NaN
#
#       OwnerUserId  ParentId PostTypeId  Score  \
# 0             8.0       NaN          1     32
# 1             8.0       NaN          1     20
# 2            25.0       NaN          1     34
# 3            11.0       NaN          1     28
# 4            25.0       NaN          1     21
# ...           ...       ...        ...    ...
# 34325      1993.0   42841.0          2      1
# 34326     36998.0       NaN          1      3
# 34327     23253.0   42882.0          2      0
# 34328     36999.0       NaN          1      2
# 34329     30375.0   42884.0          2      1
#
#                                                Tags  \
# 0                    <resources><first-time-author>
# 1       <fiction><grammatical-person><third-person>
# 2                        <publishing><novel><agent>
# 3      <plot><short-story><planning><brainstorming>
# 4                      <fiction><genre><categories>
# ...                                             ...
# 34325                                           NaN
# 34326                     <grammar><capitalization>
# 34327                                           NaN
# 34328                    <style><reader-engagement>
# 34329                                           NaN
#
#                                                    Title  ViewCount  \
# 0      What are some online guides for starting writers?     1274.0
# 1      What is the difference between writing in the ...     8426.0
# 2                                How do I find an agent?      707.0
# 3      Decide on a theme/overarching meaning before w...     3132.0
# 4                              What is Literary Fiction?      795.0
# ...                                                  ...        ...
# 34325                                                NaN        NaN
# 34326                Capitlization of A Named Experiment        8.0
# 34327                                                NaN        NaN
# 34328     What is the best way to simulate grief (loss)?        6.0
# 34329                                                NaN        NaN
#
#                                                body_text
# 0      I've always wanted to start writing (in a tota...
# 1      What kind of story is better suited for each p...
# 2      I finished my novel, and everyone I've talked ...
# 3      When writing a short-story to highlight a cert...
# 4      I keep hearing about literary fiction, and how...
# ...                                                  ...
# 34325  This answer covers a single work like a paper ...
# 34326  I have an experiment which we call 'the krypto...
# 34327  Only if Krypton is a proper noun, and then onl...
# 34328  I am new to the art of writing and have been w...
# 34329  The best way I know of is to make the reader f...
#
# [34330 rows x 23 columns]
